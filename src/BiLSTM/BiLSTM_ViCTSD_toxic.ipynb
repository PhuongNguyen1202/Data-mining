# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # DOWNLOAD FILE LIBRARY

# %%
# !pip3 install vncorenlp
# !pip install -q tf-models-official
# Out:
# Collecting vncorenlp
#   Downloading https://files.pythonhosted.org/packages/71/c2/96a60cf75421ecc740829fa920c617b3dd7fa6791e17554e7c6f3e7d7fca/vncorenlp-1.0.3.tar.gz (2.6MB)
#      |████████████████████████████████| 2.7MB 7.4MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vncorenlp) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vncorenlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vncorenlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vncorenlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vncorenlp) (2021.5.30)
# Building wheels for collected packages: vncorenlp
#   Building wheel for vncorenlp (setup.py) ... done
#   Created wheel for vncorenlp: filename=vncorenlp-1.0.3-cp37-none-any.whl size=2645952 sha256=c14fd8ddd1ee77fa369d3c8dbc19f0f4d28aaa166219a3e86a18485214f518f6
#   Stored in directory: /root/.cache/pip/wheels/09/54/8b/043667de6091d06a381d7745f44174504a9a4a56ecc9380c54
# Successfully built vncorenlp
# Installing collected packages: vncorenlp
# Successfully installed vncorenlp-1.0.3
#      |████████████████████████████████| 1.6MB 8.2MB/s
#      |████████████████████████████████| 1.2MB 44.9MB/s
#      |████████████████████████████████| 358kB 56.0MB/s
#      |████████████████████████████████| 61kB 8.8MB/s
#      |████████████████████████████████| 215kB 47.4MB/s
#      |████████████████████████████████| 38.2MB 78kB/s
#      |████████████████████████████████| 51kB 8.0MB/s
#      |████████████████████████████████| 102kB 12.7MB/s
#      |████████████████████████████████| 686kB 40.0MB/s
#      |████████████████████████████████| 645kB 40.9MB/s
#   Building wheel for seqeval (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done

# %%
# !Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.1.1.jar vncorenlp/ 
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/

# !mkdir -p pho2vec
# !wget https://public.vinai.io/word2vec_vi_words_300dims.zip
# !mv word2vec_vi_words_300dims.zip pho2vec/
# !unzip "./pho2vec/word2vec_vi_words_300dims.zip"

# %% [markdown]
# # IMPORT LIBRARY AND PATH DATASET

# %%
import pandas as pd
import numpy as np
import os
from vncorenlp import VnCoreNLP
import numpy as np
import pickle
import matplotlib.pyplot as plt
import warnings
import logging

from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors

import tensorflow as tf
# from transformers import TFAutoModel
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dropout, Dense, Embedding, LSTM, Bidirectional, Flatten, TimeDistributed, GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import matthews_corrcoef, confusion_matrix
from sklearn import metrics
from sklearn.utils import shuffle
from official.nlp import optimization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.train import CheckpointOptions

# %%
path_root = '/content/drive/MyDrive/KTDLTT'
path_img = os.path.join(path_root, 'model/ViCTSD_toxic/BiLSTM/images')
MODEL_PATH = os.path.join(path_root, 'model/ViCTSD_toxic/BiLSTM')
name_model = 'ViCTSD_toxic_BiLSTM'
file_test = os.path.join(path_root, 'src/ViCTSD_toxic_csv')


path_ViCTSD_train_toxic = os.path.join(path_root, 'data/UIT-ViCTSD/UIT-ViCTSD_train.csv')
path_ViCTSD_test_toxic = os.path.join(path_root, 'data/UIT-ViCTSD/UIT-ViCTSD_test.csv')
path_ViCTSD_dev_toxic = os.path.join(path_root, 'data/UIT-ViCTSD/UIT-ViCTSD_valid.csv')

# %% [markdown]
# # DATA LOADER AND PREPROCESSING

# %%
df_train = pd.read_csv(path_ViCTSD_train_toxic, encoding='utf-8').iloc[:, 1:]
df_test = pd.read_csv(path_ViCTSD_test_toxic, encoding='utf-8').iloc[:, 1:]
df_dev = pd.read_csv(path_ViCTSD_dev_toxic, encoding='utf-8').iloc[:, 1:]

# %%
df_train = df_train.astype({"Constructiveness": "int", "Toxicity": "int", 'Comment': "string"})
df_dev = df_dev.astype({"Constructiveness": "int", "Toxicity": "int", 'Comment': "string"})

# %%
annotator = VnCoreNLP(os.path.join(path_root, "src/vncorenlp/VnCoreNLP-1.1.1.jar"), annotators="wseg", max_heap_size='-Xmx500m') 

def preprocessing(row):
  def tokenizer(row):
    row = annotator.tokenize(row)
    return ' '.join([' '.join(words) for words in row])
  return tokenizer(row)

# %%
df_train
# Out:
#                                                 Comment  ...      Topic
# 0                                  Thật tuyệt vời...!!!  ...    SucKhoe
# 1     mỹ đã tuột dốc quá nhiều rồi, giờ muốn vực dậy...  ...    TheGioi
# 2     tôi thấy người lái xe hơi bấm còi mới là người...  ...   OtoXemay
# 3     Coi dịch là giặc. Đã mang tên đó mà xâm nhập V...  ...    SucKhoe
# 4     Thương các bé quá! Các con còn quá nhỏ mà đã p...  ...     ThoiSu
# ...                                                 ...  ...        ...
# 6995  đọc tin mà đau lòng quá,thảm nạn cứ xãy ra hoà...  ...     ThoiSu
# 6996  Nên mua bạn nhé. Để bảo vệ sức khỏe bạn trong ...  ...  KinhDoanh
# 6997  Nên ra luật người sử dụng ma túy cũng phạm tội...  ...   PhapLuat
# 6998  Mua Fadil đủ lăn bánh. Nếu thấy đắt thì đi Mor...  ...   OtoXemay
# 6999            2 kẻ này phải xử lý mạnh. Thật căm phẫn  ...   PhapLuat
#
# [7000 rows x 5 columns]

# %%
df_train.loc[:, 'Comment'] = df_train.loc[:, 'Comment'].apply(preprocessing)
df_test.loc[:, 'Comment'] = df_test.loc[:, 'Comment'].apply(preprocessing)
df_dev.loc[:, 'Comment'] = df_dev.loc[:, 'Comment'].apply(preprocessing)

# %%
df_train.head(5)
# Out:
#                                              Comment  ...     Topic
# 0                           Thật tuyệt_vời ... ! ! !  ...   SucKhoe
# 1  mỹ đã tuột_dốc quá nhiều rồi , giờ muốn vực dậ...  ...   TheGioi
# 2  tôi thấy người lái_xe hơi bấm còi mới là người...  ...  OtoXemay
# 3  Coi dịch là giặc . Đã mang tên đó mà xâm_nhập ...  ...   SucKhoe
# 4  Thương các bé quá ! Các con còn quá nhỏ mà đã ...  ...    ThoiSu
#
# [5 rows x 5 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Comment           7000 non-null   object
#  1   Constructiveness  7000 non-null   int64
#  2   Toxicity          7000 non-null   int64
#  3   Title             7000 non-null   object
#  4   Topic             7000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 273.6+ KB

# %%
# Load Pho2wv
# pho2wv = KeyedVectors.load_word2vec_format(os.path.join(path_root, 'src/word2vec_vi_words_300dims.txt'))

# %%
MAX_NB_WORDS = 75000
MAX_SEQUENCE_LENGTH = 128
DROPOUT = 0.5
nclasses = len(df_train['Toxicity'].unique())
EMBEDDING_DIM = 300
BATCH_SIZE = 50
EPOCH = 10
lr = 1e-2
STEPS_PER_EPOCH = len(df_train['Comment']) // BATCH_SIZE
VALIDATION_STEPS = len(df_dev['Comment']) // BATCH_SIZE

# %%
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, oov_token='<OOV>')
tokenizer.fit_on_texts(df_train['Comment'])
word_index = tokenizer.word_index

# %%
# loading
# with open('tokenizer_ViCTSD.pickle', 'rb') as handle:
#     tokenizer_ViCTSD = pickle.load(handle)
# def prepare_input_ViCTSD(sents, tokenizer, MAX_SEQUENCE_LENGTH=MAX_SEQUENCE_LENGTH):
#   sequences = tokenizer_ViCTSD.texts_to_sequences(sents)
#   sents = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, truncating='post', padding='post')
#   return sents

# %%
def prepare_input(sents, tokenizer, MAX_SEQUENCE_LENGTH=MAX_SEQUENCE_LENGTH):
  sequences = tokenizer.texts_to_sequences(sents)
  sents = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, truncating='post', padding='post')
  return sents

# %%
# X_train_NHUT = prepare_input_ViCTSD(df_train['Comment'], tokenizer)
# X_train = prepare_input(df_train['Comment'], tokenizer)

# %%
X_train = prepare_input(df_train['Comment'], tokenizer)
Y_train = np.array(df_train['Toxicity'].tolist())


X_dev = prepare_input(df_dev['Comment'], tokenizer)
Y_dev = np.array(df_dev['Toxicity'].tolist())

# %%
# Create embedding matrix 
# def create_embedding(EMBEDDING_DIM, word_index, embedding_dict):
#   embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
#   for word, i in word_index.items():
#     try:
#       embedding_vector = embedding_dict.get_vector(word)
#     except:
#       embedding_vector = None
#     if embedding_vector is not None:
#       if len(embedding_matrix[i]) != len(embedding_vector):
#         # words not found in embedding index will be all-zeros.
#           if len(embedding_matrix[i]) != len(embedding_vector):
#             print("could not broadcast input array from shape", str(len(embedding_matrix[i])),
#                   "into shape", str(len(embedding_vector)), " Please make sure your"
#                                                             " EMBEDDING_DIM is equal to embedding_vector file ,GloVe,")
#             exit(1)
#           embedding_matrix[i] = embedding_vector
#   return embedding_matrix
# embedding_matrix = create_embedding(EMBEDDING_DIM, word_index, embedding_dict=pho2wv)
# np.save(os.path.join(path_root, 'data/vector/pho2wv_ViCTSD.npy'), embedding_matrix)

# %%
# Load embedding matrix from file npy
embedding_matrix = np.load(os.path.join(path_root, 'data/vector/pho2wv_ViCTSD.npy'))

# %% [markdown]
# # Fine-tuning with TensorFlow

# %% [markdown]
# ## Define the model

# %%
def create_model(word_index, embedding_matrix, optimizer, nclasses=nclasses, MAX_SEQUENCE_LENGTH=MAX_SEQUENCE_LENGTH, EMBEDDING_DIM=EMBEDDING_DIM, dropout=DROPOUT, lstm_node=32):
  model = Sequential()
  
  model.add(Embedding(len(word_index) + 1,
                      EMBEDDING_DIM,
                      weights=[embedding_matrix],
                      input_length=MAX_SEQUENCE_LENGTH,
                      trainable=True))
  
  model.add(Bidirectional(LSTM(lstm_node, return_sequences=True)))
  model.add(Bidirectional(LSTM(lstm_node)))
  model.add(Dropout(dropout))
  
  model.add(Dense(nclasses, activation='softmax'))

  model.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])
  return model

# %% [markdown]
# ## Optimizer

# %%
optimizer = 'adam'

# %% [markdown]
# ## Callbacks

# %%
early_stop_callback = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

checkpoint_path = MODEL_PATH + '/checkpoints/cp-{epoch:03d}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_path, 
    save_weights_only = True,
    save_freq = 10 * STEPS_PER_EPOCH, 
    verbose = 1
)

# %% [markdown]
# ## Training

# %%
model = create_model(word_index, embedding_matrix, optimizer, nclasses, MAX_SEQUENCE_LENGTH, EMBEDDING_DIM, DROPOUT, 128)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 128, 300)          2182200
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128, 256)          439296
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 514
# =================================================================
# Total params: 3,016,250
# Trainable params: 3,016,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train,
                              validation_data=(X_dev, Y_dev),
                              epochs=EPOCH,
                              batch_size=BATCH_SIZE,
                              callbacks = [
                                  early_stop_callback, 
                                  checkpoint_callback
                              ],
                              verbose=1)
# Out:
# Epoch 1/10
# 140/140 [==============================] - 39s 209ms/step - loss: 0.3611 - accuracy: 0.8867 - val_loss: 0.3619 - val_accuracy: 0.8840
# Epoch 2/10
# 140/140 [==============================] - 24s 172ms/step - loss: 0.3516 - accuracy: 0.8916 - val_loss: 0.3599 - val_accuracy: 0.8840
# Epoch 3/10
# 140/140 [==============================] - 25s 176ms/step - loss: 0.3368 - accuracy: 0.8916 - val_loss: 0.3496 - val_accuracy: 0.8840
# Epoch 4/10
# 140/140 [==============================] - 22s 156ms/step - loss: 0.2929 - accuracy: 0.8906 - val_loss: 0.3509 - val_accuracy: 0.8840
# Epoch 5/10
# 140/140 [==============================] - 23s 166ms/step - loss: 0.2477 - accuracy: 0.9064 - val_loss: 0.3433 - val_accuracy: 0.8910
# Epoch 6/10
# 140/140 [==============================] - 22s 159ms/step - loss: 0.2167 - accuracy: 0.9190 - val_loss: 0.3671 - val_accuracy: 0.8505
# Epoch 7/10
# 140/140 [==============================] - 24s 169ms/step - loss: 0.1841 - accuracy: 0.9324 - val_loss: 0.3578 - val_accuracy: 0.8840
# Epoch 8/10
# 140/140 [==============================] - 24s 169ms/step - loss: 0.1696 - accuracy: 0.9380 - val_loss: 0.3867 - val_accuracy: 0.8525
# Epoch 9/10
# 140/140 [==============================] - 22s 157ms/step - loss: 0.1377 - accuracy: 0.9499 - val_loss: 0.3995 - val_accuracy: 0.8870
# Epoch 10/10
# 140/140 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9629
# Epoch 00010: saving model to /content/drive/MyDrive/KTDLTT/model/ViCTSD_toxic/BiLSTM/checkpoints/cp-010.ckpt
# 140/140 [==============================] - 25s 179ms/step - loss: 0.1100 - accuracy: 0.9629 - val_loss: 0.4288 - val_accuracy: 0.8775
# Epoch 00010: early stopping

# %% [markdown]
# # Predict on test data

# %%
# f1-score macro and Accuracy

# %%
X_test = prepare_input(df_test['Comment'], tokenizer)
y_test = np.array(df_test['Toxicity'].tolist())

# %%
print("\n Evaluating Model ... \n")
y_pred = model.predict(X_test, batch_size=BATCH_SIZE, verbose=1).argmax(axis=-1)
metric = metrics.classification_report(y_test, y_pred, output_dict=True)
print(metrics.classification_report(y_test, y_pred, digits=4))#, target_names=['negative', 'neutral', 'positive']))
# Out:
#  Evaluating Model ...
#
# 20/20 [==============================] - 2s 51ms/step
#               precision    recall  f1-score   support
#
#            0     0.9125    0.9730    0.9418       890
#            1     0.5294    0.2455    0.3354       110
#
#     accuracy                         0.8930      1000
#    macro avg     0.7210    0.6092    0.6386      1000
# weighted avg     0.8704    0.8930    0.8751      1000

# %%
f1 = round(metric['macro avg']['f1-score'], 4)
name_model = name_model + '_' + str(lr).replace('.', '') + '_' + str(MAX_SEQUENCE_LENGTH) + '_' + str(BATCH_SIZE) + '_' + str(DROPOUT).replace('.', '') + '_' + str(f1).replace('.', '') + '.h5'
name_img_ = 'loss' + '_' + str(lr).replace('.', '') + '_' + str(MAX_SEQUENCE_LENGTH) + '_' + str(BATCH_SIZE) + '_' + str(DROPOUT).replace('.', '') + '_' + str(f1).replace('.', '') + '.png'
model.save_weights(os.path.join(MODEL_PATH, name_model))

# %%
def plot_graphs(history, string):
  fig = plt.figure(figsize=(15, 5))
  name_img = string + '_' + str(lr).replace('.', '') + '_' + str(MAX_SEQUENCE_LENGTH) + '_' + str(BATCH_SIZE) + '_' + str(DROPOUT).replace('.', '') + '_' + str(f1).replace('.', '') + '.png'
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string], '')
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  fig.savefig(os.path.join(path_img, name_img), bbox_inches='tight') 
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def _confusion_matrix(Y_test, y_pred, metric, name_model, path_img=path_img):
  f1 = round(metric['macro avg']['f1-score'], 4)
  name_img = 'CM_' + name_model + '_' + str(f1).replace('.', '') + '.png' 
  cf_matrix = confusion_matrix(Y_test, y_pred)
  fig = plt.figure(figsize=(5, 5))
  sns.heatmap(cf_matrix, annot=True, fmt='g')
  sns.set(font_scale=1)
  fig.savefig(os.path.join(path_img, name_img), bbox_inches='tight')
  plt.show()

_confusion_matrix(y_test, y_pred, metric, name_model)

# %% [markdown]
# # Load weight

# %%
X_test = prepare_input(df_test['Comment'], tokenizer)

# %%
  # # Load model predict
from tensorflow.train import latest_checkpoint
name_model = 'ViCTSD_toxic_BiLSTM_001_128_50_05_06137.h5'
# reloaded_model = create_model(word_index, embedding_matrix, optimizer="adam", nclasses=nclasses, MAX_SEQUENCE_LENGTH=128, EMBEDDING_DIM=300, dropout=0.5, 128)
reloaded_model = create_model(word_index, embedding_matrix, optimizer="adam", nclasses=nclasses, MAX_SEQUENCE_LENGTH=128, EMBEDDING_DIM=300, dropout=0.5, lstm_node=128)
reloaded_model.load_weights(os.path.join(MODEL_PATH, name_model))
reloaded_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 128, 300)          2182200
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 128, 256)          439296
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 256)               394240
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 3,016,250
# Trainable params: 3,016,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("\n Evaluating Model ... \n")
y_pred = reloaded_model.predict(X_test, batch_size=BATCH_SIZE, verbose=1).argmax(axis=-1)
# metric = metrics.classification_report(y_test, y_pred, output_dict=True)
# print(metrics.classification_report(y_test, y_pred))#, digits=4, target_names=['negative', 'neutral', 'positive']))
# Out:
#  Evaluating Model ...
#
# 20/20 [==============================] - 1s 19ms/step
